# %%
# %run c:/Users/a/apython/__init__/DSS_init.py
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
one = pd.read_csv("one_note.csv")
one["0"]
# Out:
# 0         19
# 1          7
# 2         21
# 3          6
# 4         18
# 5          8
# 6         18
# 7          8
# 8         19
# 9          6
# 10        18
# 11         6
# 12        18
# 13         6
# 14        20
# 15         6
# 16        20
# 17         7
# 18        21
# 19         7
# 20        21
# 21         7
# 22        20
# 23         7
# 24        22
# 25         7
# 26        22
# 27         7
# 28        22
# 29         8
#         ...
# 16728   -699
# 16729   -213
# 16730   -706
# 16731   -232
# 16732   -720
# 16733   -247
# 16734   -729
# 16735   -279
# 16736   -736
# 16737   -301
# 16738   -741
# 16739   -331
# 16740   -741
# 16741   -368
# 16742   -732
# 16743   -399
# 16744   -711
# 16745   -426
# 16746   -678
# 16747   -453
# 16748   -636
# 16749   -462
# 16750   -593
# 16751   -471
# 16752   -541
# 16753   -473
# 16754   -492
# 16755   -456
# 16756   -432
# 16757   -437
# Name: 0, Length: 16758, dtype: int64

# %%
fur = np.fft.fftn(one["0"])

# %%
np.fft.fftfreq(4)
# Out:
# array([ 0.  ,  0.25, -0.5 , -0.25])

# %%
plt.figure(figsize=(10,2))
plt.plot(one["0"][10000:10200])
plt.show()

# %%
one["0"][10000:10200]
# Out:
# 10000    809
# 10001    504
# 10002    818
# 10003    507
# 10004    816
# 10005    513
# 10006    815
# 10007    519
# 10008    818
# 10009    524
# 10010    811
# 10011    525
# 10012    803
# 10013    519
# 10014    787
# 10015    516
# 10016    757
# 10017    507
# 10018    733
# 10019    490
# 10020    693
# 10021    476
# 10022    651
# 10023    453
# 10024    612
# 10025    430
# 10026    565
# 10027    408
# 10028    524
# 10029    380
#         ...
# 10170    668
# 10171    348
# 10172    670
# 10173    346
# 10174    675
# 10175    342
# 10176    681
# 10177    336
# 10178    681
# 10179    347
# 10180    681
# 10181    354
# 10182    689
# 10183    362
# 10184    693
# 10185    373
# 10186    695
# 10187    375
# 10188    706
# 10189    384
# 10190    709
# 10191    394
# 10192    717
# 10193    392
# 10194    725
# 10195    398
# 10196    727
# 10197    407
# 10198    737
# 10199    404
# Name: 0, Length: 200, dtype: int64

# %%
plt.plot(fur)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
x = np.arange(20000)
X = x / 200.
plt.plot(0.25*np.sin(2*X)- 0.5 * np.sin(3*X) - 0.25 * np.sin(4*X))
plt.show()

# %%
a = one["0"][10000:11000]
fura = np.fft.fftn(a)
plt.plot(fura)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
