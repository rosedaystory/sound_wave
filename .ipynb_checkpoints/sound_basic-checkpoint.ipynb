# %%
# %run c:/Users/a/apython/__init__/DSS_init.py
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import wave
import sys
import subprocess
import audioop
import aifc
import pydub
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pydub\utils.py:165: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
#import AudioSegment and setting ffmpeg
from pydub import AudioSegment
AudioSegment.converter = "C:/Users/a/ffmpeg/bin/ffmpeg.exe"

# %%
# load music from...file
sound = AudioSegment.from_file("C:/Users/a/GitHub/sound_wave/sonata8.mp3")
sound2 = AudioSegment.from_mp3("tchaikovsky.mp3")

# %%
#form mp3 to wave type numbers.

data = np.fromstring(sound._data, np.int16)
data2 = np.fromstring(sound2._data, np.int16)

# %%
sound_1 = pd.DataFrame(data)
sound_2 = pd.DataFrame(data2)

# %%
plt.figure(figsize = (50,10))
plt.plot(np.fromstring(sound[1050:1240]._data, np.int16))
plt.show()

# %%
sound[1050:1240]
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
plt.plot(np.fft.ifft(np.fromstring(sound[1050:1140]._data, np.int16))[:400])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize = (50,10))
plt.plot(np.fromstring(sound2[1050:1350]._data, np.int16))
plt.show()

# %%
plt.figure(figsize = (50,10))
plt.plot(np.fromstring(sound2[1050:30050]._data, np.int16))
plt.show()

# %%
plt.figure(figsize = (50,10))
plt.plot(np.fromstring(sound2[2000:3000]._data, np.int16))
plt.show()

# %%
from pydub import AudioSegment
from matplotlib import pyplot as plot
from PIL import Image, ImageDraw
import numpy as np
import os

src = "./test.mp3"

audio = AudioSegment.from_file(src)
data = np.fromstring(audio._data, np.int16)
fs = audio.frame_rate

BARS = 100
BAR_HEIGHT = 60
LINE_WIDTH = 5

length = len(data)
RATIO = length/BARS

count = 0
maximum_item = 0
max_array = []
highest_line = 0

for d in data:
	if count < RATIO:
		count = count + 1

		if abs(d) > maximum_item:
			maximum_item = abs(d)
	else:
		max_array.append(maximum_item)

		if maximum_item > highest_line:
			highest_line = maximum_item

		maximum_item = 0
		count = 1

line_ratio = highest_line/BAR_HEIGHT

im = Image.new('RGBA', (BARS * LINE_WIDTH, BAR_HEIGHT), (255, 255, 255, 1))
draw = ImageDraw.Draw(im)

current_x = 1
for item in max_array:
	item_height = item/line_ratio

	current_y = (BAR_HEIGHT - item_height)/2
	draw.line((current_x, current_y, current_x, current_y + item_height), fill=(169, 171, 172), width=4)

	current_x = current_x + LINE_WIDTH

im.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-288dddbea158> in <module>()
#       7 src = "./test.mp3"
#       8
# ----> 9 audio = AudioSegment.from_file(src)
#      10 data = np.fromstring(audio._data, np.int16)
#      11 fs = audio.frame_rate
#
# C:\ProgramData\Anaconda3\lib\site-packages\pydub\audio_segment.py in from_file(cls, file, format, codec, parameters, **kwargs)
#     430     def from_file(cls, file, format=None, codec=None, parameters=None, **kwargs):
#     431         orig_file = file
# --> 432         file = _fd_or_path_or_tempfile(file, 'rb', tempfile=False)
#     433
#     434         if format:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pydub\utils.py in _fd_or_path_or_tempfile(fd, mode, tempfile)
#      57
#      58     if isinstance(fd, basestring):
# ---> 59         fd = open(fd, mode=mode)
#      60
#      61     return fd
#
# FileNotFoundError: [Errno 2] No such file or directory: './test.mp3'

# %%
one = pd.DataFrame(np.fromstring(sound[1050:1240]._data, np.int16))
one

# %%
one.to_csv("one_note.csv")
